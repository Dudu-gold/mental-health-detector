# %% [markdown]
# **Import** libraries

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Load dataset** and display the first 5 rows

# %%
df = pd.read_csv('../data/mental_health_social_media_dataset.csv')
print(df.head())

# %% [markdown]
# **Dataset info** include column names, missing values and data types

# %%
df.info()

# %% [markdown]
# **Describe dataset**. Shows statistics like: mean, min, max etc

# %%
df.describe()

# %% [markdown]
# **Check missing values**- shows missing values count

# %%
df.isnull().sum()

# %% [markdown]
# **Check class distribution**(because of imbalance)

# %%
df['status'].value_counts()
# Out:
# status
# Normal        18391
# Depression    14506
# Suicidal      11212
# Anxiety        5503
# Name: count, dtype: int64

# %% [markdown]
# Separating X(what model reads) and Y(what model predicts)

# %%
X = df['text']
y = df['status']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# Check shape:

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (39689,)
# (9923,)

# %%
df.to_csv('mental_health_dataset_cleaned.csv', index=False)
